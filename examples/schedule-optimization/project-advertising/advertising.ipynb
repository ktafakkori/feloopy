# %% [markdown]
# ![dpp](./img/examples.png)

# %% [markdown]
# # Advertising Problem

# %% [markdown]
# --------------------
# * Developed by _Keivan Tafakkori_
# * Date: 18-4-2023
# * Contact: https://www.linkedin.com/in/keivan-tafakkori/
# * GitHub: https://github.com/ktafakkori
# --------------------

# %% [markdown]
# ### Packages

# %%
from feloopy import *

# %% [markdown]
# ### Setting

# %%
problem_name = 'ap'
solution_method = 'exact'
interface = 'linopy'
solver = 'highs'
key = 0

# %% [markdown]
# ### Model

# %%
#Environment
m = target_model(solution_method, problem_name, interface, key=key)

#Dataset
c = [50, 100]
v = [28, 24]
p = np.array([[7,  2] , [2, 12]])

#Sets
I = range(len(c)) #Set of ads
J = range(len(v)) #Set of viewer types

#Variables
x = m.pvar('x', [I])

#Objective
m.obj(sum(c[i]*x[i] for i in I))

#Constraints
for j in J:
    m.con(sum(p[i,j]*x[i] for i in I) >= v[j])
    
#Solve
m.sol(['min'], solver)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 24
#      21     m.con(sum(p[i,j]*x[i] for i in I) >= v[j])
#      23 #Solve
# ---> 24 m.sol(['min'], solver)
#
# File ~/anaconda3/lib/python3.10/site-packages/feloopy/feloopy.py:1528, in Model.sol(self, directions, solver_name, solver_options, objective_id, email, debug, time_limit, cpu_threads, absolute_gap, relative_gap, show_log, save_log, save_model, max_iterations, obj_operators)
#    1517     for i in range(len(self.features['directions'])):
#    1519         self.features['directions'][i] = directions[i]
#    1521 match self.features['solution_method']:
#    1522
#    1523     case 'exact':
#    1524
#    1525         self.features['model_object_before_solve'] = self.model
#    1526
#    1527         from .generators import solution_generator
# -> 1528         self.solution = solution_generator.generate_solution(
#    1529             self.features)
#    1530
#    1531         try:
#    1532             self.obj_val = self.get_objective()
#    1533             self.status = self.get_status()
#    1534             self.cpt = self.get_time()*10**6
#    1535
#    1536         except:
#    1537             "None"
#    1538
#    1539     case 'heuristic':
#    1540
#    1541         if self.features['agent_status'] == 'idle':
#    1542
#    1543             "Do nothing"
#    1544
#    1545         else:
#    1546
#    1547             if self.features['vectorized']:
#    1548
#    1549                 self.penalty = np.zeros(np.shape(self.agent)[0])
#    1550
#    1551                 if self.features['penalty_coefficient'] != 0 and len(self.features['constraints']) == 1:
#    1552
#    1553                     self.features['constraints'][0] = np.reshape(
#    1554                         self.features['constraints'][0], [np.shape(self.agent)[0], 1])
#    1555                     self.features['constraints'].append(
#    1556                         np.zeros(shape=(np.shape(self.agent)[0], 1)))
#    1557                     self.penalty = np.amax(np.concatenate(
#    1558                         self.features['constraints'], axis=1), axis=1)
#    1559
#    1560                     self.agent[np.where(self.penalty == 0), -2] = 1
#    1561                     self.agent[np.where(self.penalty > 0), -2] = -1
#    1562
#    1563                 if self.features['penalty_coefficient'] != 0 and len(self.features['constraints']) > 1:
#    1564
#    1565                     self.features['constraints'].append(
#    1566                         np.zeros(shape=(np.shape(self.agent)[0], 1)))
#    1567                     self.penalty = np.amax(np.concatenate(
#    1568                         self.features['constraints'], axis=1), axis=1)
#    1569                     self.agent[np.where(self.penalty == 0), -2] = 1
#    1570                     self.agent[np.where(self.penalty > 0), -2] = -1
#    1571
#    1572                 else:
#    1573
#    1574                     self.agent[:, -2] = 2
#    1575
#    1576                 if type(objective_id) != str:
#    1577
#    1578                     if directions[objective_id] == 'max':
#    1579                         self.agent[:, -1] = np.reshape(self.features['objectives'][objective_id], [self.agent.shape[0],]) - np.reshape(
#    1580                             self.features['penalty_coefficient'] * (self.penalty)**2, [self.agent.shape[0],])
#    1581
#    1582                     if directions[objective_id] == 'min':
#    1583                         self.agent[:, -1] = np.reshape(self.features['objectives'][objective_id], [self.agent.shape[0],]) + np.reshape(
#    1584                             self.features['penalty_coefficient'] * (self.penalty)**2, [self.agent.shape[0],])
#    1585
#    1586                 else:
#    1587
#    1588                     self.agent[:, -1] = 0
#    1589
#    1590                     total_obj = self.features['objective_counter'][0]
#    1591
#    1592                     self.features['objectives'] = np.array(
#    1593                         self.features['objectives']).T[0]
#    1594
#    1595                     for i in range(self.features['objective_counter'][0]):
#    1596
#    1597                         if directions[i] == 'max':
#    1598                             self.agent[:, -2-total_obj+i] = self.features['objectives'][:,
#    1599                                                                                         i] - self.features['penalty_coefficient'] * (self.penalty)**2
#    1600
#    1601                         if directions[i] == 'min':
#    1602                             self.agent[:, -2-total_obj+i] = self.features['objectives'][:,
#    1603                                                                                         i] + self.features['penalty_coefficient'] * (self.penalty)**2
#    1604
#    1605             else:
#    1606
#    1607                 self.penalty = 0
#    1608
#    1609                 if len(self.features['constraints']) >= 1:
#    1610
#    1611                     self.penalty = np.amax(
#    1612                         np.array([0]+self.features['constraints'], dtype=object))
#    1613
#    1614                 if type(objective_id) != str:
#    1615
#    1616                     if directions[objective_id] == 'max':
#    1617                         self.response = self.features['objectives'][objective_id] - \
#    1618                             self.features['penalty_coefficient'] * \
#    1619                             (self.penalty-0)**2
#    1620
#    1621                     if directions[objective_id] == 'min':
#    1622                         self.response = self.features['objectives'][objective_id] + \
#    1623                             self.features['penalty_coefficient'] * \
#    1624                             (self.penalty-0)**2
#    1625
#    1626                 else:
#    1627
#    1628                     total_obj = self.features['objective_counter'][0]
#    1629
#    1630                     self.response = [None for i in range(total_obj)]
#    1631
#    1632                     for i in range(total_obj):
#    1633
#    1634                         if directions[i] == 'max':
#    1635
#    1636                             self.response[i] = self.features['objectives'][i] - \
#    1637                                 self.features['penalty_coefficient'] * \
#    1638                                 (self.penalty)**2
#    1639
#    1640                         if directions[i] == 'min':
#    1641
#    1642                             self.response[i] = self.features['objectives'][i] + \
#    1643                                 self.features['penalty_coefficient'] * \
#    1644                                 (self.penalty)**2
#
# File ~/anaconda3/lib/python3.10/site-packages/feloopy/generators/solution_generator.py:100, in generate_solution(features)
#      12 def generate_solution(features):
#      14     match features['interface_name']:
#      15
#      16         case 'pulp':
#      17
#      18             from .solution import pulp_solution_generator
#      19             ModelSolution = pulp_solution_generator.generate_solution(features)
#      20
#      21         case 'pyomo':
#      22
#      23             from .solution import pyomo_solution_generator
#      24             ModelSolution = pyomo_solution_generator.generate_solution(
#      25                 features)
#      26
#      27         case 'ortools':
#      28
#      29             from .solution import ortools_solution_generator
#      30             ModelSolution = ortools_solution_generator.generate_solution(
#      31                 features)
#      32
#      33         case 'ortools_cp':
#      34
#      35             from .solution import ortools_cp_solution_generator
#      36             ModelSolution = ortools_cp_solution_generator.generate_solution(
#      37                 features)
#      38
#      39         case 'gekko':
#      40
#      41             from .solution import gekko_solution_generator
#      42             ModelSolution = gekko_solution_generator.generate_solution(
#      43                 features)
#      44
#      45         case 'picos':
#      46
#      47             from .solution import picos_solution_generator
#      48             ModelSolution = picos_solution_generator.generate_solution(
#      49                 features)
#      50
#      51         case 'cvxpy':
#      52
#      53             from .solution import cvxpy_solution_generator
#      54             ModelSolution = cvxpy_solution_generator.generate_solution(
#      55                 features)
#      56
#      57         case 'cylp':
#      58
#      59             from .solution import cylp_solution_generator
#      60             ModelSolution = cylp_solution_generator.generate_solution(features)
#      61
#      62         case 'pymprog':
#      63
#      64             from .solution import pymprog_solution_generator
#      65             ModelSolution = pymprog_solution_generator.generate_solution(
#      66                 features)
#      67
#      68         case 'cplex':
#      69
#      70             from .solution import cplex_solution_generator
#      71             ModelSolution = cplex_solution_generator.generate_solution(
#      72                 features)
#      73
#      74         case 'cplex_cp':
#      75
#      76             from .solution import cplex_cp_solution_generator
#      77             ModelSolution = cplex_cp_solution_generator.generate_solution(
#      78                 features)
#      79
#      80         case 'gurobi':
#      81
#      82             from .solution import gurobi_solution_generator
#      83             ModelSolution = gurobi_solution_generator.generate_solution(
#      84                 features)
#      85
#      86         case 'xpress':
#      87
#      88             from .solution import xpress_solution_generator
#      89             ModelSolution = xpress_solution_generator.generate_solution(
#      90                 features)
#      91
#      92         case 'mip':
#      93
#      94             from .solution import mip_solution_generator
#      95             ModelSolution = mip_solution_generator.generate_solution(features)
#      96
#      97         case 'linopy':
#      98
#      99             from .solution import linopy_solution_generator
# --> 100             ModelSolution = linopy_solution_generator.generate_solution(
#     101                 features)
#     102
#     103         case 'rsome_ro':
#     104
#     105             from .solution import rsome_ro_solution_generator
#     106             ModelSolution = rsome_ro_solution_generator.generate_solution(
#     107                 features)
#     108
#     109         case 'rsome_dro':
#     110
#     111             from .solution import rsome_dro_solution_generator
#     112             ModelSolution = rsome_dro_solution_generator.generate_solution(
#     113                 features)
#     115     return ModelSolution
#
# File ~/anaconda3/lib/python3.10/site-packages/feloopy/generators/solution/linopy_solution_generator.py:53, in generate_solution(features)
#      43 if solver_name not in linopy_solver_selector.keys():
#      44     raise RuntimeError(
#      45         "Using solver '%s' is not supported by 'linopy'! \nPossible fixes: \n1) Check the solver name. \n2) Use another interface. \n" % (solver_name))
#      47 match debug:
#      48
#      49     case False:
#      50
#      51         match directions[objective_id]:
#      52             case "min":
# ---> 53                 model_object.add_objective(model_objectives[objective_id])
#      54             case "max":
#      55                 model_object.add_objective(-model_objectives[objective_id])
#      56
#      57         for constraint in model_constraints:
#      58             model_object.add_constraints(constraint)
#      59
#      60         time_solve_begin = timeit.default_timer()
#      61         result = model_object.solve(solver_name=solver_name)
#      62         time_solve_end = timeit.default_timer()
#      63         generated_solution = [result, [time_solve_begin, time_solve_end]]
#      65 return generated_solution
#
# File ~/anaconda3/lib/python3.10/site-packages/linopy/model.py:664, in Model.add_objective(self, expr, overwrite)
#     662 if isinstance(expr, (list, tuple)):
#     663     expr = self.linexpr(*expr)
# --> 664 assert isinstance(expr, LinearExpression)
#     666 if self.chunk is not None:
#     667     expr = expr.chunk(self.chunk)
#
# AssertionError:

# %% [markdown]
# ### Result

# %%
#Report
m.report()
# Out:
# +--------------------------------------------------------------------------------+
# |                                 FelooPy v0.2.5                                 |
# +--------------------------------------------------------------------------------+
# | Date: 2023-06-05                                                Time: 18:04:13 |
# | Interface: pulp                                                  Solver: highs |
# +--------------------------------------------------------------------------------+
# |                               Model Information                                |
# +--------------------------------------------------------------------------------+
# |                              The 'ap' model has:                               |
# |                     2 positive variable(s) in 1 class(es).                     |
# |                                1 objective(s).                                 |
# |                        2 constraint(s) in 1 class(es).                         |
# |                 Total number of variables is 2 in 1 class(es).                 |
# +--------------------------------------------------------------------------------+
# |                               Solve Information                                |
# +--------------------------------------------------------------------------------+
# | Method: exact                                               Objective Value(s) |
# | Status:                                                                    min |
# | Optimal                                                                 320.00 |
# +--------------------------------------------------------------------------------+
# |                               Metric Information                               |
# +--------------------------------------------------------------------------------+
# | CPT   (microseconds):  3.18e+04                                                |
# | CPT   (hour:min:sec):  00:00:00                                                |
# +--------------------------------------------------------------------------------+
# |                              Decision Information                              |
# +--------------------------------------------------------------------------------+
# | x[0] = 3.6                                                                     |
# | x[1] = 1.4                                                                     |
# +--------------------------------------------------------------------------------+
